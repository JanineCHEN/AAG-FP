# %%
from graph_extractor import graph_extractor
from methods import *
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# Using backend: pytorch
# CubiCasa5k Model for walls/doors/windows/rooms loaded.
# Detectron 2 Mask R-CNN for Wall/Door/Windows loaded.
# Detectron 2 Mask R-CNN for Stairs loaded.
# LOAD MODELS--- 9.895519018173218 seconds ---

# %%
import os
import pandas as pd
import networkx as nx

# %%
out_dir = './outputs/ipynb_samples'
img_dir = './FP_sample_images/01.jpeg'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
G,G_n,G_m = graph_extractor(img_dir, out_dir)
draw_img(img_dir,out_dir)
draw_simple_graph(G_n,out_dir)
draw_multigraph(G_m,out_dir)
nx.write_gpickle(G, os.path.join(out_dir,"G.gpickle"))
nx.write_gpickle(G_n, os.path.join(out_dir,"G_n.gpickle"))
nx.write_gpickle(G_m, os.path.join(out_dir,"G_m.gpickle"))
# Out:
# Detect the background/Binarization--- 11.13680624961853 seconds ---
# /home/jieliin/.virtualenvs/integration_FP/lib/python3.6/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Filter out text--- 14.402546644210815 seconds ---
# Extract mask background--- 14.45311975479126 seconds ---
# CubiCasa5k_model--- 21.566696643829346 seconds ---
# /home/jieliin/.virtualenvs/integration_FP/lib/python3.6/site-packages/detectron2/modeling/roi_heads/fast_rcnn.py:124: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   filter_inds = filter_mask.nonzero()
# Mask R-CNN: Wall/Door/Window--- 31.089003562927246 seconds ---
# ...
